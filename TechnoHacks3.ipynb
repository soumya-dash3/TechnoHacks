# %% [markdown]
# train.csv

# %% [markdown]
# 1.Cleaning the dataset by removing missing values and outliers.

# %%
import pandas as pd

# %%
file_path = r"C:\Users\soumy\Downloads\DA_Titanic_Data\train.csv"

# %%
df = pd.read_csv(r"C:\Users\soumy\Downloads\DA_Titanic_Data\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
missing_values = df.isna()

# %%
df_cleaned = df.dropna()
#rows

# %%
df_cleaned = df.dropna(axis=1)
#columns

# %%
import pandas as pd

# Define a function to remove outliers using the IQR method
def remove_outliers_iqr(data, columns):
    data_cleaned = data.copy()  # Create a copy of the original data
    for column in columns:
        Q1 = data_cleaned[column].quantile(0.25)
        Q3 = data_cleaned[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        data_cleaned = data_cleaned[(data_cleaned[column] >= lower_bound) & (data_cleaned[column] <= upper_bound)]
    return data_cleaned

# Read your dataset into a pandas DataFrame
df = pd.read_csv(r'C:\Users\soumy\Downloads\DA_Titanic_Data\train.csv')

# Specify the numerical columns for which you want to remove outliers
numerical_columns = ['Age', 'Fare']  # Add all your numerical columns

# Call the function to remove outliers
df_cleaned = remove_outliers_iqr(df, numerical_columns)

# The df_cleaned DataFrame now contains your data with outliers removed

# %% [markdown]
# 2.Calculating summary statistics for the  dataset

# %%
means = df_cleaned.mean(numeric_only=True)

# %%
medians = df_cleaned.median(numeric_only=True)

# %%
modes = df_cleaned.mode(numeric_only=True)

# %%
std_devs = df_cleaned.std(numeric_only=True)

# %%
print("Mean:")
print(means)

print("\nMedian:")
print(medians)

print("\nMode:")
print(modes)

print("\nStandard Deviation:")
print(std_devs)
# Out:
# Mean:
# PassengerId    449.467875
# Survived         0.360791
# Pclass           2.433278
# Age             28.246705
# SibSp            0.495881
# Parch            0.403624
# Fare            18.933401
# dtype: float64
#
# Median:
# PassengerId    447.0
# Survived         0.0
# Pclass           3.0
# Age             28.0
# SibSp            0.0
# Parch            0.0
# Fare            13.0
# dtype: float64
#
# Mode:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# 0              1       0.0     3.0  22.0    0.0    0.0  13.0
# 1              3       NaN     NaN  24.0    NaN    NaN   NaN
# 2              4       NaN     NaN   NaN    NaN    NaN   NaN
# 3              5       NaN     NaN   NaN    NaN    NaN   NaN
# 4              7       NaN     NaN   NaN    NaN    NaN   NaN
# ..           ...       ...     ...   ...    ...    ...   ...
# 602          886       NaN     NaN   NaN    NaN    NaN   NaN
# 603          887       NaN     NaN   NaN    NaN    NaN   NaN
# 604          888       NaN     NaN   NaN    NaN    NaN   NaN
# 605          890       NaN     NaN   NaN    NaN    NaN   NaN
# 606          891       NaN     NaN   NaN    NaN    NaN   NaN
#
# [607 rows x 7 columns]
#
# Standard Deviation:
# PassengerId    262.357612
# Survived         0.480626
# Pclass           0.734631
# Age             13.429036
# SibSp            0.959355
# Parch            0.852207
# Fare            14.184362
# dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read your dataset into a pandas DataFrame
df = pd.read_csv(r'C:\Users\soumy\Downloads\DA_Titanic_Data\train.csv')

# Specify the numerical columns for which you want to create histograms
numerical_columns = ['Age', 'Fare']  # Add all your numerical columns

# Set the number of bins for the histograms (you can adjust this as needed)
num_bins = 20

# Create a loop to plot histograms for each numerical column
for column in numerical_columns:
    plt.figure(figsize=(8, 6))  # Set the figure size
    plt.hist(df[column], bins=num_bins, edgecolor='k')  # Plot the histogram
    plt.title(f'Histogram of {column}')  # Set the title
    plt.xlabel(column)  # Set the x-axis label
    plt.ylabel('Frequency')  # Set the y-axis label
    plt.grid(axis='y', alpha=0.75)  # Add grid lines
    plt.show()  # Show the histogram plot
